# %%
from estimate_entropy import meta_main, get_args
from tools import plot_entropy, plot_pdf
from os.path import join

import sys
sys.path.append('./doe')

from doe.main import get_args, meta_main
from tools import plot_mi_run, plot_mi_bias_var_mse, collect_mi
from mi_estimators import main

cuda = False

# %%
main(False)
# Out:
# Training Loop:   0%|          | 0/5000 [00:00<?, ?it/s]/home/mmproj02/proj/synthetic_experiments/mi_estimators.py:110: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_x = torch.tensor(batch_x).float().to(device)
# /home/mmproj02/proj/synthetic_experiments/mi_estimators.py:111: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_y = torch.tensor(batch_y).float().to(device)
# Training Loop: 100%|██████████| 5000/5000 [00:15<00:00, 322.93it/s]
# finish training for TUBA with true MI value = 2.000000
# Training Loop: 100%|██████████| 5000/5000 [00:15<00:00, 333.06it/s]
# finish training for TUBA with true MI value = 4.000000
# Training Loop: 100%|██████████| 5000/5000 [00:15<00:00, 329.31it/s]
# finish training for TUBA with true MI value = 6.000000
# Training Loop: 100%|██████████| 5000/5000 [00:15<00:00, 328.27it/s]
# finish training for TUBA with true MI value = 8.000000
# Training Loop: 100%|██████████| 5000/5000 [00:15<00:00, 328.84it/s]
# MI: 100%|██████████| 5/5 [01:16<00:00, 15.23s/it]
# Models:  50%|█████     | 1/2 [01:16<01:16, 76.94s/it]
# finish training for TUBA with true MI value = 10.000000
# model TUBA average time cost is 0.003045 s
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 154.10it/s]
# finish training for MIKernelEstimator with true MI value = 2.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 152.39it/s]
# finish training for MIKernelEstimator with true MI value = 4.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 154.13it/s]
# finish training for MIKernelEstimator with true MI value = 6.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 153.58it/s]
# finish training for MIKernelEstimator with true MI value = 8.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 154.61it/s]
# MI: 100%|██████████| 5/5 [02:42<00:00, 32.52s/it]
# Models: 100%|██████████| 2/2 [03:59<00:00, 119.78s/it]
# finish training for MIKernelEstimator with true MI value = 10.000000
# model KNIFE average time cost is 0.006504 s
# Second part
# 2it [00:00, 2714.76it/s]
# Training Loop:   0%|          | 0/5000 [00:00<?, ?it/s]/home/mmproj02/proj/synthetic_experiments/mi_estimators.py:110: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_x = torch.tensor(batch_x).float().to(device)
# /home/mmproj02/proj/synthetic_experiments/mi_estimators.py:111: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_y = torch.tensor(batch_y).float().to(device)
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 352.12it/s]
# finish training for TUBA with true MI value = 2.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 348.50it/s]
# finish training for TUBA with true MI value = 4.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 355.93it/s]
# finish training for TUBA with true MI value = 6.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 352.29it/s]
# finish training for TUBA with true MI value = 8.000000
# Training Loop: 100%|██████████| 5000/5000 [00:13<00:00, 358.78it/s]
# MI: 100%|██████████| 5/5 [01:10<00:00, 14.15s/it]
# Models:  50%|█████     | 1/2 [01:10<01:10, 70.74s/it]
# finish training for TUBA with true MI value = 10.000000
# model TUBA average time cost is 0.002830 s
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 152.93it/s]
# finish training for MIKernelEstimator with true MI value = 2.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 156.21it/s]
# finish training for MIKernelEstimator with true MI value = 4.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 152.20it/s]
# finish training for MIKernelEstimator with true MI value = 6.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 153.95it/s]
# finish training for MIKernelEstimator with true MI value = 8.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 152.72it/s]
# MI: 100%|██████████| 5/5 [02:42<00:00, 32.56s/it]
# Models: 100%|██████████| 2/2 [03:53<00:00, 116.76s/it]
# finish training for MIKernelEstimator with true MI value = 10.000000
# model KNIFE average time cost is 0.006511 s
# Second part
# 2it [00:00, 2172.09it/s]
# Training Loop:   0%|          | 0/5000 [00:00<?, ?it/s]/home/mmproj02/proj/synthetic_experiments/mi_estimators.py:110: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_x = torch.tensor(batch_x).float().to(device)
# /home/mmproj02/proj/synthetic_experiments/mi_estimators.py:111: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_y = torch.tensor(batch_y).float().to(device)
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 353.18it/s]
# finish training for TUBA with true MI value = 2.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 347.90it/s]
# finish training for TUBA with true MI value = 4.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 346.71it/s]
# finish training for TUBA with true MI value = 6.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 354.43it/s]
# finish training for TUBA with true MI value = 8.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 345.76it/s]
# MI: 100%|██████████| 5/5 [01:11<00:00, 14.31s/it]
# Models:  50%|█████     | 1/2 [01:11<01:11, 71.53s/it]
# finish training for TUBA with true MI value = 10.000000
# model TUBA average time cost is 0.002861 s
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 153.36it/s]
# finish training for MIKernelEstimator with true MI value = 2.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 152.75it/s]
# finish training for MIKernelEstimator with true MI value = 4.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 153.08it/s]
# finish training for MIKernelEstimator with true MI value = 6.000000
# Training Loop: 100%|██████████| 5000/5000 [00:33<00:00, 150.33it/s]
# finish training for MIKernelEstimator with true MI value = 8.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 152.77it/s]
# MI: 100%|██████████| 5/5 [02:43<00:00, 32.80s/it]
# Models: 100%|██████████| 2/2 [03:55<00:00, 117.77s/it]
# finish training for MIKernelEstimator with true MI value = 10.000000
# model KNIFE average time cost is 0.006560 s
# Second part
# 2it [00:00, 2854.24it/s]
# Training Loop:   0%|          | 0/5000 [00:00<?, ?it/s]/home/mmproj02/proj/synthetic_experiments/mi_estimators.py:110: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_x = torch.tensor(batch_x).float().to(device)
# /home/mmproj02/proj/synthetic_experiments/mi_estimators.py:111: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_y = torch.tensor(batch_y).float().to(device)
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 346.82it/s]
# finish training for TUBA with true MI value = 2.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 344.90it/s]
# finish training for TUBA with true MI value = 4.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 356.68it/s]
# finish training for TUBA with true MI value = 6.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 350.04it/s]
# finish training for TUBA with true MI value = 8.000000
# Training Loop: 100%|██████████| 5000/5000 [00:13<00:00, 358.68it/s]
# MI: 100%|██████████| 5/5 [01:11<00:00, 14.23s/it]
# Models:  50%|█████     | 1/2 [01:11<01:11, 71.17s/it]
# finish training for TUBA with true MI value = 10.000000
# model TUBA average time cost is 0.002847 s
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 151.65it/s]
# finish training for MIKernelEstimator with true MI value = 2.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 151.80it/s]
# finish training for MIKernelEstimator with true MI value = 4.000000
# Training Loop: 100%|██████████| 5000/5000 [00:33<00:00, 151.45it/s]
# finish training for MIKernelEstimator with true MI value = 6.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 152.68it/s]
# finish training for MIKernelEstimator with true MI value = 8.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 151.97it/s]
# MI: 100%|██████████| 5/5 [02:44<00:00, 32.92s/it]
# Models: 100%|██████████| 2/2 [03:55<00:00, 117.88s/it]
# finish training for MIKernelEstimator with true MI value = 10.000000
# model KNIFE average time cost is 0.006584 s
# Second part
# 2it [00:00, 2734.23it/s]
# Training Loop:   0%|          | 0/5000 [00:00<?, ?it/s]/home/mmproj02/proj/synthetic_experiments/mi_estimators.py:110: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_x = torch.tensor(batch_x).float().to(device)
# /home/mmproj02/proj/synthetic_experiments/mi_estimators.py:111: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_y = torch.tensor(batch_y).float().to(device)
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 351.35it/s]
# finish training for TUBA with true MI value = 2.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 349.39it/s]
# finish training for TUBA with true MI value = 4.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 345.13it/s]
# finish training for TUBA with true MI value = 6.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 349.43it/s]
# finish training for TUBA with true MI value = 8.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 345.52it/s]
# MI: 100%|██████████| 5/5 [01:11<00:00, 14.36s/it]
# Models:  50%|█████     | 1/2 [01:11<01:11, 71.83s/it]
# finish training for TUBA with true MI value = 10.000000
# model TUBA average time cost is 0.002873 s
# Training Loop: 100%|██████████| 5000/5000 [00:33<00:00, 150.19it/s]
# finish training for MIKernelEstimator with true MI value = 2.000000
# Training Loop: 100%|██████████| 5000/5000 [00:33<00:00, 149.84it/s]
# finish training for MIKernelEstimator with true MI value = 4.000000
# Training Loop: 100%|██████████| 5000/5000 [00:33<00:00, 150.30it/s]
# finish training for MIKernelEstimator with true MI value = 6.000000
# Training Loop: 100%|██████████| 5000/5000 [00:33<00:00, 151.22it/s]
# finish training for MIKernelEstimator with true MI value = 8.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 151.78it/s]
# MI: 100%|██████████| 5/5 [02:45<00:00, 33.19s/it]
# Models: 100%|██████████| 2/2 [03:57<00:00, 118.89s/it]
# finish training for MIKernelEstimator with true MI value = 10.000000
# model KNIFE average time cost is 0.006638 s
# Second part
# 2it [00:00, 2199.43it/s]
# Training Loop:   0%|          | 0/5000 [00:00<?, ?it/s]/home/mmproj02/proj/synthetic_experiments/mi_estimators.py:110: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_x = torch.tensor(batch_x).float().to(device)
# /home/mmproj02/proj/synthetic_experiments/mi_estimators.py:111: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_y = torch.tensor(batch_y).float().to(device)
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 346.10it/s]
# finish training for TUBA with true MI value = 2.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 344.02it/s]
# finish training for TUBA with true MI value = 4.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 349.58it/s]
# finish training for TUBA with true MI value = 6.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 343.67it/s]
# finish training for TUBA with true MI value = 8.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 344.53it/s]
# MI: 100%|██████████| 5/5 [01:12<00:00, 14.47s/it]
# Models:  50%|█████     | 1/2 [01:12<01:12, 72.36s/it]
# finish training for TUBA with true MI value = 10.000000
# model TUBA average time cost is 0.002894 s
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 155.37it/s]
# finish training for MIKernelEstimator with true MI value = 2.000000
# Training Loop: 100%|██████████| 5000/5000 [00:33<00:00, 150.81it/s]
# finish training for MIKernelEstimator with true MI value = 4.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 155.63it/s]
# finish training for MIKernelEstimator with true MI value = 6.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 154.69it/s]
# finish training for MIKernelEstimator with true MI value = 8.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 155.45it/s]
# MI: 100%|██████████| 5/5 [02:41<00:00, 32.39s/it]
# Models: 100%|██████████| 2/2 [03:54<00:00, 117.17s/it]
# finish training for MIKernelEstimator with true MI value = 10.000000
# model KNIFE average time cost is 0.006479 s
# Second part
# 2it [00:00, 2663.05it/s]
# Training Loop:   0%|          | 0/5000 [00:00<?, ?it/s]/home/mmproj02/proj/synthetic_experiments/mi_estimators.py:110: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_x = torch.tensor(batch_x).float().to(device)
# /home/mmproj02/proj/synthetic_experiments/mi_estimators.py:111: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_y = torch.tensor(batch_y).float().to(device)
# Training Loop: 100%|██████████| 5000/5000 [00:15<00:00, 320.03it/s]
# finish training for TUBA with true MI value = 2.000000
# Training Loop: 100%|██████████| 5000/5000 [00:15<00:00, 328.51it/s]
# finish training for TUBA with true MI value = 4.000000
# Training Loop: 100%|██████████| 5000/5000 [00:15<00:00, 325.03it/s]
# finish training for TUBA with true MI value = 6.000000
# Training Loop: 100%|██████████| 5000/5000 [00:15<00:00, 326.11it/s]
# finish training for TUBA with true MI value = 8.000000
# Training Loop: 100%|██████████| 5000/5000 [00:14<00:00, 334.82it/s]
# MI: 100%|██████████| 5/5 [01:16<00:00, 15.30s/it]
# Models:  50%|█████     | 1/2 [01:16<01:16, 76.51s/it]
# finish training for TUBA with true MI value = 10.000000
# model TUBA average time cost is 0.003060 s
# Training Loop: 100%|██████████| 5000/5000 [00:33<00:00, 148.92it/s]
# finish training for MIKernelEstimator with true MI value = 2.000000
# Training Loop: 100%|██████████| 5000/5000 [00:33<00:00, 151.20it/s]
# finish training for MIKernelEstimator with true MI value = 4.000000
# Training Loop: 100%|██████████| 5000/5000 [00:33<00:00, 149.56it/s]
# finish training for MIKernelEstimator with true MI value = 6.000000
# Training Loop: 100%|██████████| 5000/5000 [00:33<00:00, 150.35it/s]
# finish training for MIKernelEstimator with true MI value = 8.000000
# Training Loop: 100%|██████████| 5000/5000 [00:33<00:00, 149.75it/s]
# MI: 100%|██████████| 5/5 [02:46<00:00, 33.35s/it]
# Models: 100%|██████████| 2/2 [04:03<00:00, 121.62s/it]
# finish training for MIKernelEstimator with true MI value = 10.000000
# model KNIFE average time cost is 0.006669 s
# Second part
# 2it [00:00, 2874.78it/s]
# Training Loop:   0%|          | 0/5000 [00:00<?, ?it/s]/home/mmproj02/proj/synthetic_experiments/mi_estimators.py:110: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_x = torch.tensor(batch_x).float().to(device)
# /home/mmproj02/proj/synthetic_experiments/mi_estimators.py:111: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   batch_y = torch.tensor(batch_y).float().to(device)
# Training Loop: 100%|██████████| 5000/5000 [00:15<00:00, 326.91it/s]
# finish training for TUBA with true MI value = 2.000000
# Training Loop: 100%|██████████| 5000/5000 [00:15<00:00, 317.61it/s]
# finish training for TUBA with true MI value = 4.000000
# Training Loop: 100%|██████████| 5000/5000 [00:15<00:00, 320.61it/s]
# finish training for TUBA with true MI value = 6.000000
# Training Loop: 100%|██████████| 5000/5000 [00:15<00:00, 328.27it/s]
# finish training for TUBA with true MI value = 8.000000
# Training Loop: 100%|██████████| 5000/5000 [00:15<00:00, 329.99it/s]
# MI: 100%|██████████| 5/5 [01:17<00:00, 15.41s/it]
# Models:  50%|█████     | 1/2 [01:17<01:17, 77.03s/it]
# finish training for TUBA with true MI value = 10.000000
# model TUBA average time cost is 0.003081 s
# Training Loop: 100%|██████████| 5000/5000 [00:33<00:00, 149.84it/s]
# finish training for MIKernelEstimator with true MI value = 2.000000
# Training Loop: 100%|██████████| 5000/5000 [00:32<00:00, 152.04it/s]
# finish training for MIKernelEstimator with true MI value = 4.000000
# Training Loop:  97%|█████████▋| 4832/5000 [00:32<00:01, 152.09it/s]
